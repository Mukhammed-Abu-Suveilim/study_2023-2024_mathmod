# %%
using PLots
using DifferentialEquations
# Out:
# ArgumentError: Package PLots not found in current path.
# - Run `import Pkg; Pkg.add("PLots")` to install the PLots package.
#
# Stacktrace:
#  [1] macro expansion
#    @ .\loading.jl:1772 [inlined]
#  [2] macro expansion
#    @ .\lock.jl:267 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base .\loading.jl:1753
#  [4] #invoke_in_world#3
#    @ .\essentials.jl:926 [inlined]
#  [5] invoke_in_world
#    @ .\essentials.jl:923 [inlined]
#  [6] require(into::Module, mod::Symbol)
#    @ Base .\loading.jl:1746

# %%
import Pkg

# %%
Pkg.add("Plots")
Pkg.add("DifferentialEquations")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\moham\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\moham\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\moham\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\moham\.julia\environments\v1.10\Manifest.toml`

# %%
#Вариант 36
1032215135%70 + 1
# Out:
# 36

# %%
using Plots
using DifferentialEquations

# %%
#x'' + g * x' + w^2 * x = f(t)
#для колебании гармонического осциллятора без затуханий и без действий внешней силы x'' + 6x = 0
#g - затухание
#w - частота
#f(t) - внешняя сила, действующая на осциллятор

w = 6
g = 0
#f(t) = 0

function caseOne(du, u, p, t)
    x, y = u
    du[1] = u[2]  
    du[2] = -g*u[2] - w*u[1]
end
# Out:
# caseOne (generic function with 1 method)

# %%
x0 = 0.6
y0 = 1.6
u0 = [x0, y0]
# Out:
# 2-element Vector{Float64}:
#  0.6
#  1.6

# %%
tspan = (0, 60) #интервал временни
# Out:
# (0, 60)

# %%
probOne = ODEProblem(caseOne, u0, tspan)
# Out:
# ODEProblem with uType Vector{Float64} and tType Int64. In-place: true
# timespan: (0, 60)
# u0: 2-element Vector{Float64}:
#  0.6
#  1.6

# %%
solOne = solve(probOne, dtmax = 0.05)
# Out:
# retcode: Success
# Interpolation: specialized 4th order "free" interpolation, specialized 2nd order "free" stiffness-aware interpolation
# t: 1202-element Vector{Float64}:
#   0.0
#   0.05
#   0.1
#   0.15000000000000002
#   0.2
#   0.25
#   0.3
#   0.35
#   0.39999999999999997
#   0.44999999999999996
#   0.49999999999999994
#   0.5499999999999999
#   0.6
#   ⋮
#  59.49999999999876
#  59.549999999998754
#  59.59999999999875
#  59.64999999999875
#  59.699999999998745
#  59.74999999999874
#  59.79999999999874
#  59.84999999999874
#  59.899999999998734
#  59.94999999999873
#  59.99999999999873
#  60.0
# u: 1202-element Vector{Vector{Float64}}:
#  [0.6, 1.6]
#  [0.675305772099772, 1.408464654766059]
#  [0.7404946132364214, 1.1958287352429844]
#  [0.7945899124739966, 0.9652777953035426]
#  [0.8367812541056088, 0.7202657783875519]
#  [0.8664365587013092, 0.4644632730792007]
#  [0.8831115524539384, 0.20170252306727873]
#  [0.8865564229602222, -0.06407998469163345]
#  [0.8767195617251325, -0.3289024935053928]
#  [0.8537483373220841, -0.5887976286761579]
#  [0.8179868876260552, -0.8398718337698501]
#  [0.7699709641947616, -1.0783637009950395]
#  [0.7104199060355468, -1.3007003218287225]
#  ⋮
#  [0.8156945237336597, -0.8531430900172635]
#  [0.7670338664022082, -1.0908495559902214]
#  [0.7068820757669092, -1.3122137217394387]
#  [0.6361403014094615, -1.5139192732815847]
#  [0.5558683442044456, -1.6929444074330091]
#  [0.46726877916747156, -1.8466071022269974]
#  [0.37166893936688966, -1.9726052969804635]
#  [0.2705010308027563, -2.0690513800620813]
#  [0.16528067615721184, -2.1345004676916575]
#  [0.05758420885791212, -2.1679720501187174]
#  [-0.0509749423819604, -2.1689646808932896]
#  [-0.05097494238471905, -2.1689646808929006]

# %%
X = [u[1] for u in solOne.u]
Y = [u[2] for u in solOne.u]
Time = [t for t in solOne.t]
# Out:
# 1202-element Vector{Float64}:
#   0.0
#   0.05
#   0.1
#   0.15000000000000002
#   0.2
#   0.25
#   0.3
#   0.35
#   0.39999999999999997
#   0.44999999999999996
#   0.49999999999999994
#   0.5499999999999999
#   0.6
#   ⋮
#  59.49999999999876
#  59.549999999998754
#  59.59999999999875
#  59.64999999999875
#  59.699999999998745
#  59.74999999999874
#  59.79999999999874
#  59.84999999999874
#  59.899999999998734
#  59.94999999999873
#  59.99999999999873
#  60.0

# %%
plt = plot(layout = (1, 2), dpi = 300, legend = false)
# Out:
# attempt to save state beyond implementation limit

# %%
plot!(
    plt[1], 
    Time, 
    X, 
    title = "Решение Уравнения", 
    color=:red)
plot!(
    plt[2], 
    X, 
    Y, 
    title = "Фазовый Портрет", 
    color=:blue)

# %%
savefig(plt, "lab4_1.png")
# Out:
# "C:\\Users\\moham\\lab4_1.png"
